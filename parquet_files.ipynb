# %%
import numpy as np
import pandas as pd

# # ========== LOADING ==========

# # Option 1: Load using pandas
df = pd.read_parquet("data/christian_df_fits.parquet")
pd.set_option('display.max_columns', None)
pd.options.display.min_rows = 100
df

# # Option 2: Load using parquest lib
# from fastparquet import ParquetFile
# pf = ParquetFile('data/christian_df_fits.parquet')
# df = pf.to_pandas()


# # ========== SAVING ==========

# # Save to parquet file
# df = pd.DataFrame({
#     'student': ['personA007', 'personB', 'x', 'personD', 'personE'],
#     'marks': [20,10,22,21,22],
# })
# df.to_parquet('sample.parquet')
# Out:
#                A            μ           σ     P     c     b      ν_n  \
# 0       0.307664  5782.603885    0.250320  None  None  None  55749.0
# 1       0.094192  5882.394362    0.667096  None  None  None  55740.0
# 2       0.330616  6014.285015   10.754669  None  None  None  55379.0
# 3       0.065528  6270.490360    1.296312  None  None  None  55007.0
# 4       0.450000  6372.500000   -0.005158  None  None  None  54650.0
# 5       0.320124  6523.724788    0.166689  None  None  None  54636.0
# 6       2.007660  1444.009240  -48.724885  None  None  None  54808.0
# 7       0.042818  1504.458048    3.078136  None  None  None  54800.0
# 8       0.450000  6974.500000   -0.048404  None  None  None  53902.0
# 9            NaN          NaN         NaN  None  None  None      NaN
# 10           NaN          NaN         NaN  None  None  None      NaN
# 11           NaN          NaN         NaN  None  None  None      NaN
# 12           NaN          NaN         NaN  None  None  None      NaN
# ...
